# %%
# Simple Address Book using Tuples

# Step 1: Create an empty list to store contacts
contacts = []

# Step 2: Function to add a contact
def add_contact():
    name = input("Enter name: ")
    phone = input("Enter phone number: ")
    email = input("Enter email: ")
    contact = (name, phone, email)  # Store as tuple
    contacts.append(contact)
    print("✅ Contact added successfully!")

# Step 3: Function to search contact by name
def search_contact():
    name = input("Enter name to search: ")
    found = False
    for c in contacts:
        if c[0].lower() == name.lower():
            print(f"Name: {c[0]}, Phone: {c[1]}, Email: {c[2]}")
            found = True
            break
    if not found:
        print("❌ Contact not found!")

# Step 4: Function to display all contacts
def show_contacts():
    if not contacts:
        print("No contacts available.")
    else:
        print("\n------ ALL CONTACTS ------")
        for c in contacts:
            print(f"Name: {c[0]}, Phone: {c[1]}, Email: {c[2]}")

# Step 5: Main loop
while True:
    print("\n------ ADDRESS BOOK MENU ------")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. View All Contacts")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        add_contact()
    elif choice == "2":
        search_contact()
    elif choice == "3":
        show_contacts()
    elif choice == "4":
        print("👋 Exiting Address Book. Goodbye!")
        break
    else:
        print("Invalid choice. Try again.")
# Out:
# ------ ADDRESS BOOK MENU ------
# 1. Add Contact
# 2. Search Contact
# 3. View All Contacts
# 4. Exit
# Enter your choice (1-4):  1
# Enter name:  Noah
# Enter phone number:  1122334455
# Enter email:  noah_25@gmail.com
# ✅ Contact added successfully!
#
# ------ ADDRESS BOOK MENU ------
# 1. Add Contact
# 2. Search Contact
# 3. View All Contacts
# 4. Exit
# Enter your choice (1-4):  3
# ------ ALL CONTACTS ------
# Name: Noah, Phone: 1122334455, Email: noah_25@gmail.com
#
# ------ ADDRESS BOOK MENU ------
# 1. Add Contact
# 2. Search Contact
# 3. View All Contacts
# 4. Exit
